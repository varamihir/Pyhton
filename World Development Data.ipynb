# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import random
import os

# %%
# Get data into python
os.getcwd()
# Out:
# 'C:\\Users\\nipin\\Documents\\Python\\edx\\World Development Indicator'

# %%
wdi = pd.read_csv("WDIData.csv", )

# %%
wdi.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2010       2011       2012  \
# 0   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN     ...       82.407647  82.827636  83.169227
# ...

# %%
wdi.shape
# Out:
# (422136, 64)

# %%
type(wdi)
# Out:
# pandas.core.frame.DataFrame

# %%
wdi.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', 'Unnamed: 63'],
#       dtype='object')

# %%
del wdi["Unnamed: 63"]

# %%
#id_vars["Country Name","Country Code","Indicator Name","Indicator Code"]
wdi = wdi.rename({"Country Name":"CountryName","Country Code":"CountryCode","Indicator Name":"IndicatorName","Indicator Code":"IndicatorCode"},axis = 1)

# %%
wdi.columns
wdi.shape
# Out:
# (422136, 63)

# %%
wdi.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', '1960',
#        '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# Melting the data frame from wide format to long format
# Option 1, id_vars are those variables we need to keep them as it is,var_name - changing remaining columns into that variable
# name, value_name will be the values of var_name variables.
wdi1 = wdi.melt(id_vars = ["CountryName","CountryCode","IndicatorName","IndicatorCode"],
              var_name = "Year", value_name ="Values")

# %%
 wdi1.head(50)
wdi1.tail(50)
# Out:
#          CountryName CountryCode  \
# 24905974    Zimbabwe         ZWE
# 24905975    Zimbabwe         ZWE
# 24905976    Zimbabwe         ZWE
# 24905977    Zimbabwe         ZWE
# 24905978    Zimbabwe         ZWE
# 24905979    Zimbabwe         ZWE
# 24905980    Zimbabwe         ZWE
# 24905981    Zimbabwe         ZWE
# 24905982    Zimbabwe         ZWE
# 24905983    Zimbabwe         ZWE
# 24905984    Zimbabwe         ZWE
# 24905985    Zimbabwe         ZWE
# 24905986    Zimbabwe         ZWE
# 24905987    Zimbabwe         ZWE
# 24905988    Zimbabwe         ZWE
# 24905989    Zimbabwe         ZWE
# 24905990    Zimbabwe         ZWE
# 24905991    Zimbabwe         ZWE
# 24905992    Zimbabwe         ZWE
# 24905993    Zimbabwe         ZWE
# 24905994    Zimbabwe         ZWE
# 24905995    Zimbabwe         ZWE
# 24905996    Zimbabwe         ZWE
# 24905997    Zimbabwe         ZWE
# 24905998    Zimbabwe         ZWE
# 24905999    Zimbabwe         ZWE
# 24906000    Zimbabwe         ZWE
# ...

# %%
# Option 2 to melt to define the value_vars
# wdi_new =wdi.melt(id_vars= ["CountryName","CountryCode","IndicatorName","IndicatorCode"],
         #     value_vars = [1960, 1961, 1962, 1963, 1964, 1965,
                     #       1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,1978, 1979, 1980, 1981,1982,1983,1984,1985,
                     #       1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000, 2001,2002, 2003,2004,2005,2006,
                      #     2007,2008,2009,2010,2011,2012,2013,2014,2015, 2016,2017, 2018],
              #  var_name = "Year", value_name= "Value")

# %%
wdi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24906024 entries, 0 to 24906023
# Data columns (total 6 columns):
# CountryName      object
# CountryCode      object
# IndicatorName    object
# IndicatorCode    object
# Year             object
# Values           float64
# dtypes: float64(1), object(5)
# memory usage: 1.1+ GB

# %%
# Convert year into category
wdi1.Year = wdi1.Year.astype("category")

# %%
wdi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24906024 entries, 0 to 24906023
# Data columns (total 6 columns):
# CountryName      object
# CountryCode      object
# IndicatorName    object
# IndicatorCode    object
# Year             category
# Values           float64
# dtypes: category(1), float64(1), object(4)
# memory usage: 973.8+ MB

# %%
# How many unique countries are there
wdi_uni_coun = wdi1["CountryName"].unique().tolist()
len(wdi_uni_coun)
# Out:
# 264

# %%
# Country code should be same?
wdi_uni_cd = wdi1["CountryCode"].unique().tolist()
len(wdi_uni_cd)
# Out:
# 264

# %%
# How many indicators
wdi_uni_ind = wdi1["IndicatorName"].unique().tolist()
len(wdi_uni_ind)
# Out:
# 1599

# %%
# how many years of data we have
wdi_years = wdi1["Year"].unique().tolist()
len(wdi_years)
# Out:
# 59

# %%
print(min(wdi_years),"to",max(wdi_years))
# Out:
# 1960 to 2018

# %% [markdown]
# ### Lets pick a country and indicator to explore: CO2 emission per capita and USA

# %%
hist_indicator = "CO2 emission\(metric"
hist_country = "USA"

# %%
mask1 = wdi_new["IndicatorName"].str.contains(hist_indicator)
mask2 = wdi_new["CountryCode"].str.contains(hist_country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6294b6f74090> in <module>
# ----> 1 mask1 = wdi_new["IndicatorName"].str.contains(hist_indicator)
#       2 mask2 = wdi_new["CountryCode"].str.contains(hist_country)
#
# NameError: name 'wdi_new' is not defined

# %%
# stage is just those indicator matching the USA for countrycode and Indicator name
stage = wdi_new[mask1 & mask2]

# %%
stage.head()

# %%
wdi_USA = wdi_new["CountryCode"]=="USA"
wdi_new[wdi_USA]

# %%
hist_indicator = "GDP per capita \(constant 2005"
hist_country = "USA"
mask1 =wdi1["IndicatorName"].str.contains(hist_indicator)
mask2 = wdi1["CountryCode"].str.contains(hist_country)
len(mask2)
wd1i1[mask2].head()

# %%
gdp_stage = wdi1[mask1 & mask2]
gdp_stage.head()
